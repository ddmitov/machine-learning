# %%
# !pip install huggingface_hub

# %%
from huggingface_hub import snapshot_download

model_id="profile/model"

snapshot_download(
    repo_id=model_id,
    local_dir="/tmp/pytorch_model",
    local_dir_use_symlinks=False,
    revision="main"
)

# %%
from urllib.request import urlretrieve

# %%
urlretrieve(
    "https://raw.githubusercontent.com/ggerganov/llama.cpp/master/convert-hf-to-gguf.py",
    "/tmp/convert-hf-to-gguf.py"
)

# %%
# !pip install llama_cpp_python gguf

# %%
# !python /tmp/convert-hf-to-gguf.py /tmp/pytorch_model --outfile /tmp/gguf/model.gguf
