# %%
# !pip install https://huggingface.co/latincy/la_core_web_lg/resolve/main/la_core_web_lg-any-py3-none-any.whl

# %%
import spacy

text = 'Dis Manibus Cai Cassi Felicis vixit annis LXX et Cassiae Lacaenae coniugi eius vixit annis LX et Vetsidio Supero filio piissimo qui vixit annis XII Hic siti sunt Cassia Cogitata parentibus et filio faciendum curavit'

# %%
la_core_web_nlp = spacy.load('la_core_web_lg')

la_core_web_document = la_core_web_nlp(text)

for form in la_core_web_document:
  print(f'{form.text} -- {form.lemma_}')
# Out:
# Dis -- dis
# Manibus -- Manibus
# Cai -- Cai
# Cassi -- Cassius
# Felicis -- Felices
# vixit -- vixit
# annis -- annus
# LXX -- LXX
# et -- et
# Cassiae -- Cassia
# Lacaenae -- Lacaena
# coniugi -- coniunx
# eius -- is
# vixit -- vixit
# annis -- annus
# LX -- LX
# et -- et
# Vetsidio -- Uetsidius
# Supero -- Supero
# filio -- filius
# piissimo -- pius
# qui -- qui
# vixit -- vixit
# annis -- annus
# XII -- XII
# Hic -- Hic
# siti -- siti
# sunt -- sum
# Cassia -- Cassia
# Cogitata -- Cogitata
# parentibus -- parens
# et -- et
# filio -- filius
# faciendum -- facio
# curavit -- curo
